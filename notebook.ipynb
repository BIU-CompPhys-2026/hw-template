# %% [markdown]
# # Homework N: [Topic]
#
# **Name:**
# **ID:**
# **Date:**

# %%
from solution import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: [Task Name]
#
# ### Physics Explanation
#
# *Explain the physics behind your implementation here. What physical constraints must the code satisfy? How did you verify correctness?*

# %%
# Your code, plots, and analysis here

# %% [markdown]
# ## Prompt History
#
# Paste your LLM conversation link or key excerpts below.
#
# **LLM used:**
# **Link to conversation:**
#
# ### Key prompts and corrections
#
# 1. *Describe what you asked the LLM and what you had to fix/correct based on physics*
